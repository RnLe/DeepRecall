# %%
# load the conversation data from exampleConversation.txt
# each line is a segment from a single speaker (possibly containing multiple sentences)

import os
import re  # added to split segments into sentences

def load_conversation(file_path):
    """
    Load conversation data from a file and split each segment into sentences.
    
    Args:
        file_path (str): Path to the conversation file.
    
    Returns:
        list: List of individual sentences.
    """
    
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"The file {file_path} does not exist.")
    
    conversation = []
    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line:
                # Split the segment into sentences using punctuation as delimiters
                sentences = re.split(r'(?<=[.!?])\s+', line)
                conversation.extend(sentences)
    
    return conversation

fileName = "exampleConversation.txt"
conversation = load_conversation(fileName)

def chunk_sentences(sentences, chunk_size):
    """
    Splits a list of sentences into chunks with a two-sentence overlap.
    
    Args:
        sentences (list): List of sentences.
        chunk_size (int): Number of sentences per chunk (must be >= 3).
    
    Returns:
        list: A list of chunks, each a list of sentences.
    """
    if chunk_size < 3:
        raise ValueError("chunk_size must be at least 3")
    
    chunks = []
    # The step is chunk_size minus the two overlapping sentences
    step = chunk_size - 2
    total = len(sentences)
    
    for i in range(0, total, step):
        if i + chunk_size > total:
            break  # or optionally add the last chunk even if incomplete
        chunks.append(sentences[i : i + chunk_size])
    
    return chunks

# Example usage:
# This will create, for example, chunks like:
# [sentences[0], sentences[1], sentences[2]], then [sentences[1], sentences[2], sentences[3]], etc.
chunks = chunk_sentences(conversation, 3)
print(f"Total chunks (chunk size 3): {len(chunks)}")
for i, chunk in enumerate(chunks, start=1):
    print(f"Chunk {i}: {chunk}")

# Printing some statistics about the conversation
print(f"Number of sentences: {len(conversation)}")
# Number of words in the conversation
word_count = sum(len(sentence.split()) for sentence in conversation)
print(f"Total number of words: {word_count}")
# Out:
# Total chunks (chunk size 3): 133
# Chunk 1: ['Microsoft co-founder and philanthropist Bill Gates  is the pioneering tech titan  who helped lead the computer revolution  and plans to donate the majority  of his multi-billion dollar fortune to global causes.', "Now he's sharing his journey  and how it began in his new memoir, Source Code.", 'Please welcome, for the very first time,  on The View, Bill Gates.']
# Chunk 2: ["Now he's sharing his journey  and how it began in his new memoir, Source Code.", 'Please welcome, for the very first time,  on The View, Bill Gates.', 'So, first of all, welcome to The View.']
# Chunk 3: ['Please welcome, for the very first time,  on The View, Bill Gates.', 'So, first of all, welcome to The View.', 'Wow.']
# Chunk 4: ['So, first of all, welcome to The View.', 'Wow.', "But secondly, it's kind of great to have you  at such an important time for the country  because it seems like today's tech billionaires  are shifting rightward and seem to have more power  than even the VP, whose name I can't remember."]
# Chunk 5: ['Wow.', "But secondly, it's kind of great to have you  at such an important time for the country  because it seems like today's tech billionaires  are shifting rightward and seem to have more power  than even the VP, whose name I can't remember.", "Well, there's no club of these people."]
# Chunk 6: ["But secondly, it's kind of great to have you  at such an important time for the country  because it seems like today's tech billionaires  are shifting rightward and seem to have more power  than even the VP, whose name I can't remember.", "Well, there's no club of these people.", "We're, you know, kind of individual."]
# Chunk 7: ["Well, there's no club of these people.", "We're, you know, kind of individual.", "And, you know, I'm very focused on global health  and, you know, hope the transition to this administration  doesn't interrupt some incredible work that's been going on."]
# Chunk 8: ["We're, you know, kind of individual.", "And, you know, I'm very focused on global health  and, you know, hope the transition to this administration  doesn't interrupt some incredible work that's been going on.", "Well, they had some VIP seating at the inauguration  and we did notice you weren't there."]
# Chunk 9: ["And, you know, I'm very focused on global health  and, you know, hope the transition to this administration  doesn't interrupt some incredible work that's been going on.", "Well, they had some VIP seating at the inauguration  and we did notice you weren't there.", 'What do you make of that visual?']
# Chunk 10: ["Well, they had some VIP seating at the inauguration  and we did notice you weren't there.", 'What do you make of that visual?', 'You know, they clearly wanted to fund the inauguration.']
# Chunk 11: ['What do you make of that visual?', 'You know, they clearly wanted to fund the inauguration.', 'And they wanted it to be a great inauguration  just for the good of the country, no doubt.']
# Chunk 12: ['You know, they clearly wanted to fund the inauguration.', 'And they wanted it to be a great inauguration  just for the good of the country, no doubt.', 'Well said.']
# Chunk 13: ['And they wanted it to be a great inauguration  just for the good of the country, no doubt.', 'Well said.', 'I feel good calling you Bill, Mr.']
# Chunk 14: ['Well said.', 'I feel good calling you Bill, Mr.', 'Gates.']
# Chunk 15: ['I feel good calling you Bill, Mr.', 'Gates.', 'Shortly before President Trump took office,  you had a three-hour dinner with him.']
# Chunk 16: ['Gates.', 'Shortly before President Trump took office,  you had a three-hour dinner with him.', "And that's more face time than, as you say,  you had with Joe Biden during his presidency."]
# Chunk 17: ['Shortly before President Trump took office,  you had a three-hour dinner with him.', "And that's more face time than, as you say,  you had with Joe Biden during his presidency.", 'And by your account, you say that you were impressed with him.']
# Chunk 18: ["And that's more face time than, as you say,  you had with Joe Biden during his presidency.", 'And by your account, you say that you were impressed with him.', 'What are you able to share about issues you discussed?']
# Chunk 19: ['And by your account, you say that you were impressed with him.', 'What are you able to share about issues you discussed?', "And since he's only been in office two weeks,  but do you feel like what you discussed aligned  with what you're seeing so far?"]
# Chunk 20: ['What are you able to share about issues you discussed?', "And since he's only been in office two weeks,  but do you feel like what you discussed aligned  with what you're seeing so far?", 'Well, my two priorities in talking to President Trump  were the global health issues, particularly HIV and polio.']
# Chunk 21: ["And since he's only been in office two weeks,  but do you feel like what you discussed aligned  with what you're seeing so far?", 'Well, my two priorities in talking to President Trump  were the global health issues, particularly HIV and polio.', 'Mm-hmm.']
# Chunk 22: ['Well, my two priorities in talking to President Trump  were the global health issues, particularly HIV and polio.', 'Mm-hmm.', 'The voters have a lot to be proud of.']
# Chunk 23: ['Mm-hmm.', 'The voters have a lot to be proud of.', "You know, we've saved tens of millions of lives."]
# Chunk 24: ['The voters have a lot to be proud of.', "You know, we've saved tens of millions of lives.", 'Mm-hmm.']
# Chunk 25: ["You know, we've saved tens of millions of lives.", 'Mm-hmm.', 'The number of children who die at the turn of the century  is over 10 million a year.']
# Chunk 26: ['Mm-hmm.', 'The number of children who die at the turn of the century  is over 10 million a year.', 'Mm-hmm.']
# Chunk 27: ['The number of children who die at the turn of the century  is over 10 million a year.', 'Mm-hmm.', 'Now down below 5 million.']
# Chunk 28: ['Mm-hmm.', 'Now down below 5 million.', 'Mm-hmm.']
# Chunk 29: ['Now down below 5 million.', 'Mm-hmm.', 'And things like HIV medicines, malaria bed nets,  Yeah.']
# Chunk 30: ['Mm-hmm.', 'And things like HIV medicines, malaria bed nets,  Yeah.', 'are responsible for that and vaccines.']
# Chunk 31: ['And things like HIV medicines, malaria bed nets,  Yeah.', 'are responsible for that and vaccines.', 'You know, so I was encouraged him to drive more innovation  in those spaces.']
# Chunk 32: ['are responsible for that and vaccines.', 'You know, so I was encouraged him to drive more innovation  in those spaces.', 'And we were missing, still missing some vaccines.']
# Chunk 33: ['You know, so I was encouraged him to drive more innovation  in those spaces.', 'And we were missing, still missing some vaccines.', 'And, you know, I felt we had a very good conversation.']
# Chunk 34: ['And we were missing, still missing some vaccines.', 'And, you know, I felt we had a very good conversation.', 'Mm-hmm.']
# Chunk 35: ['And, you know, I felt we had a very good conversation.', 'Mm-hmm.', 'Okay.']
# Chunk 36: ['Mm-hmm.', 'Okay.', 'Well, and you, Mr.']
# Chunk 37: ['Okay.', 'Well, and you, Mr.', "Gates,  you also called Elon Musk's political influence abroad,  quote, insane, along with another word we can't repeat here."]
# Chunk 38: ['Well, and you, Mr.', "Gates,  you also called Elon Musk's political influence abroad,  quote, insane, along with another word we can't repeat here.", "But what's your take on his political access and influence  here in America right now?"]
# Chunk 39: ["Gates,  you also called Elon Musk's political influence abroad,  quote, insane, along with another word we can't repeat here.", "But what's your take on his political access and influence  here in America right now?", 'Well, Elon, his private sector work, you know,  has been very innovative, really fantastic.']
# Chunk 40: ["But what's your take on his political access and influence  here in America right now?", 'Well, Elon, his private sector work, you know,  has been very innovative, really fantastic.', 'Mm-hmm.']
# Chunk 41: ['Well, Elon, his private sector work, you know,  has been very innovative, really fantastic.', 'Mm-hmm.', "A lot of private sector people, when they get into government,  they don't take the time necessarily to see  what the good work is or why it's structured the way it is."]
# Chunk 42: ['Mm-hmm.', "A lot of private sector people, when they get into government,  they don't take the time necessarily to see  what the good work is or why it's structured the way it is.", "So I'm a little worried, particularly with this USAID stuff."]
# Chunk 43: ["A lot of private sector people, when they get into government,  they don't take the time necessarily to see  what the good work is or why it's structured the way it is.", "So I'm a little worried, particularly with this USAID stuff.", 'Mm-hmm.']
# Chunk 44: ["So I'm a little worried, particularly with this USAID stuff.", 'Mm-hmm.', 'My foundation partners with USAID on nutrition  and getting vaccines out.']
# Chunk 45: ['Mm-hmm.', 'My foundation partners with USAID on nutrition  and getting vaccines out.', "And, you know, there's incredible people."]
# Chunk 46: ['My foundation partners with USAID on nutrition  and getting vaccines out.', "And, you know, there's incredible people.", "You know, they're not actually worms that work there."]
# Chunk 47: ["And, you know, there's incredible people.", "You know, they're not actually worms that work there.", 'Yeah.']
# Chunk 48: ["You know, they're not actually worms that work there.", 'Yeah.', "So, you know, hopefully we'll get some of that work  back in shape."]
# Chunk 49: ['Yeah.', "So, you know, hopefully we'll get some of that work  back in shape.", "In fact, if we don't, you know,  you could have literally millions of deaths."]
# Chunk 50: ["So, you know, hopefully we'll get some of that work  back in shape.", "In fact, if we don't, you know,  you could have literally millions of deaths.", 'So, you know, with aid, people think, you know,  wow, how much do we give these countries?']
# Chunk 51: ["In fact, if we don't, you know,  you could have literally millions of deaths.", 'So, you know, with aid, people think, you know,  wow, how much do we give these countries?', "As you said, it's less than a percent."]
# Chunk 52: ['So, you know, with aid, people think, you know,  wow, how much do we give these countries?', "As you said, it's less than a percent.", "Some people think it's five percent and it should be two percent,  but it's actually under one percent."]
# Chunk 53: ["As you said, it's less than a percent.", "Some people think it's five percent and it should be two percent,  but it's actually under one percent.", 'Yeah.']
# Chunk 54: ["Some people think it's five percent and it should be two percent,  but it's actually under one percent.", 'Yeah.', 'Wow.']
# Chunk 55: ['Yeah.', 'Wow.', 'And still saving lives.']
# Chunk 56: ['Wow.', 'And still saving lives.', 'Well, your Gates Foundation is the biggest funder of vaccines in the world.']
# Chunk 57: ['And still saving lives.', 'Well, your Gates Foundation is the biggest funder of vaccines in the world.', "I think a lot of people don't recognize that."]
# Chunk 58: ['Well, your Gates Foundation is the biggest funder of vaccines in the world.', "I think a lot of people don't recognize that.", 'And it was key to developing the COVID vaccine.']
# Chunk 59: ["I think a lot of people don't recognize that.", 'And it was key to developing the COVID vaccine.', 'Mm-hmm.']
# Chunk 60: ['And it was key to developing the COVID vaccine.', 'Mm-hmm.', 'That has made you, unfortunately, a target of all kinds of baseless conspiracies,  including from RFK Jr., who apparently does have a worm in his brain.']
# Chunk 61: ['Mm-hmm.', 'That has made you, unfortunately, a target of all kinds of baseless conspiracies,  including from RFK Jr., who apparently does have a worm in his brain.', 'And he now claims he is not anti-vax.']
# Chunk 62: ['That has made you, unfortunately, a target of all kinds of baseless conspiracies,  including from RFK Jr., who apparently does have a worm in his brain.', 'And he now claims he is not anti-vax.', 'Do you believe him?']
# Chunk 63: ['And he now claims he is not anti-vax.', 'Do you believe him?', "Well, we'll do our best to work with him."]
# Chunk 64: ['Do you believe him?', "Well, we'll do our best to work with him.", "Under his management is going to be the FDA, which is a fantastic regulator,  you know, passing judgment on a lot of the new innovations we're funding."]
# Chunk 65: ["Well, we'll do our best to work with him.", "Under his management is going to be the FDA, which is a fantastic regulator,  you know, passing judgment on a lot of the new innovations we're funding.", 'NIH does fantastic research.']
# Chunk 66: ["Under his management is going to be the FDA, which is a fantastic regulator,  you know, passing judgment on a lot of the new innovations we're funding.", 'NIH does fantastic research.', 'Yeah.']
# Chunk 67: ['NIH does fantastic research.', 'Yeah.', 'And so those have been partners of our foundation.']
# Chunk 68: ['Yeah.', 'And so those have been partners of our foundation.', 'And, you know, I hope the great scientists there get the support they deserve.']
# Chunk 69: ['And so those have been partners of our foundation.', 'And, you know, I hope the great scientists there get the support they deserve.', 'Mm-hmm.']
# Chunk 70: ['And, you know, I hope the great scientists there get the support they deserve.', 'Mm-hmm.', 'And just to follow up, before COVID, you say you spent the most sleepless nights worrying about pandemics.']
# Chunk 71: ['Mm-hmm.', 'And just to follow up, before COVID, you say you spent the most sleepless nights worrying about pandemics.', 'After COVID, has that changed?']
# Chunk 72: ['And just to follow up, before COVID, you say you spent the most sleepless nights worrying about pandemics.', 'After COVID, has that changed?', 'And if it has, what keeps you up now?']
# Chunk 73: ['After COVID, has that changed?', 'And if it has, what keeps you up now?', 'Because we all need to know.']
# Chunk 74: ['And if it has, what keeps you up now?', 'Because we all need to know.', 'Yeah.']
# Chunk 75: ['Because we all need to know.', 'Yeah.', 'Yeah, the pandemic, sadly, was fairly predictable.']
# Chunk 76: ['Yeah.', 'Yeah, the pandemic, sadly, was fairly predictable.', "And it won't be the last pandemic."]
# Chunk 77: ['Yeah, the pandemic, sadly, was fairly predictable.', "And it won't be the last pandemic.", 'The next one could be far more severe.']
# Chunk 78: ["And it won't be the last pandemic.", 'The next one could be far more severe.', 'I mean, this one, it killed millions.']
# Chunk 79: ['The next one could be far more severe.', 'I mean, this one, it killed millions.', 'It was awful.']
# Chunk 80: ['I mean, this one, it killed millions.', 'It was awful.', 'We got the vaccine.']
# Chunk 81: ['It was awful.', 'We got the vaccine.', "You know, actually, President Trump's leadership was a factor in getting that out quickly."]
# Chunk 82: ['We got the vaccine.', "You know, actually, President Trump's leadership was a factor in getting that out quickly.", "And so I, when I spoke to him, I said, okay, here's some other medical innovations,  including a thing called an HIV cure that could be accelerated."]
# Chunk 83: ["You know, actually, President Trump's leadership was a factor in getting that out quickly.", "And so I, when I spoke to him, I said, okay, here's some other medical innovations,  including a thing called an HIV cure that could be accelerated.", 'Mm-hmm.']
# Chunk 84: ["And so I, when I spoke to him, I said, okay, here's some other medical innovations,  including a thing called an HIV cure that could be accelerated.", 'Mm-hmm.', 'So, you know, we should be more prepared, both for a pandemic.']
# Chunk 85: ['Mm-hmm.', 'So, you know, we should be more prepared, both for a pandemic.', "I'd say that's still number one."]
# Chunk 86: ['So, you know, we should be more prepared, both for a pandemic.', "I'd say that's still number one.", 'Mm-hmm.']
# Chunk 87: ["I'd say that's still number one.", 'Mm-hmm.', 'You know, you can worry about nuclear war.']
# Chunk 88: ['Mm-hmm.', 'You know, you can worry about nuclear war.', 'You can worry about AI.']
# Chunk 89: ['You know, you can worry about nuclear war.', 'You can worry about AI.', 'Oh, this sounds like fun.']
# Chunk 90: ['You can worry about AI.', 'Oh, this sounds like fun.', "There's plenty to worry about."]
# Chunk 91: ['Oh, this sounds like fun.', "There's plenty to worry about.", 'Well, do you sleep at all?']
# Chunk 92: ["There's plenty to worry about.", 'Well, do you sleep at all?', "But overall, I'm an optimist."]
# Chunk 93: ['Well, do you sleep at all?', "But overall, I'm an optimist.", 'Do you sleep at all?']
# Chunk 94: ["But overall, I'm an optimist.", 'Do you sleep at all?', 'Okay.']
# Chunk 95: ['Do you sleep at all?', 'Okay.', "No, I mean, you know, it's up to the government to think ahead on behalf of the citizens."]
# Chunk 96: ['Okay.', "No, I mean, you know, it's up to the government to think ahead on behalf of the citizens.", 'Yes.']
# Chunk 97: ["No, I mean, you know, it's up to the government to think ahead on behalf of the citizens.", 'Yes.', "So, a pandemic, there's a lot that we should be doing that hopefully will get our act together  before the next one comes."]
# Chunk 98: ['Yes.', "So, a pandemic, there's a lot that we should be doing that hopefully will get our act together  before the next one comes.", 'Which is...']
# Chunk 99: ["So, a pandemic, there's a lot that we should be doing that hopefully will get our act together  before the next one comes.", 'Which is...', 'You know, overall, the innovation in health, both in the developing countries, the rich world,  you know, I love being part of that.']
# Chunk 100: ['Which is...', 'You know, overall, the innovation in health, both in the developing countries, the rich world,  you know, I love being part of that.', 'I was reading, though, that you said the next pandemic, you are predicting within maybe 25 years.']
# Chunk 101: ['You know, overall, the innovation in health, both in the developing countries, the rich world,  you know, I love being part of that.', 'I was reading, though, that you said the next pandemic, you are predicting within maybe 25 years.', 'Is that accurate?']
# Chunk 102: ['I was reading, though, that you said the next pandemic, you are predicting within maybe 25 years.', 'Is that accurate?', "Oh, certainly we'll have one in the next 25 years."]
# Chunk 103: ['Is that accurate?', "Oh, certainly we'll have one in the next 25 years.", "Uh, you know, there's even some pathogens out there that we're watching over right now."]
# Chunk 104: ["Oh, certainly we'll have one in the next 25 years.", "Uh, you know, there's even some pathogens out there that we're watching over right now.", 'Mm-hmm.']
# Chunk 105: ["Uh, you know, there's even some pathogens out there that we're watching over right now.", 'Mm-hmm.', 'Um, you know, so maybe 10% chance in the next four years.']
# Chunk 106: ['Mm-hmm.', 'Um, you know, so maybe 10% chance in the next four years.', 'Yeah.']
# Chunk 107: ['Um, you know, so maybe 10% chance in the next four years.', 'Yeah.', 'Um...']
# Chunk 108: ['Yeah.', 'Um...', "Well, let's talk about AI, which you mentioned."]
# Chunk 109: ['Um...', "Well, let's talk about AI, which you mentioned.", "Last week, Silicon Valley and stocks were rocked by news that China's AI model may outperform  ours at a fraction of the cost and quicker to develop it."]
# Chunk 110: ["Well, let's talk about AI, which you mentioned.", "Last week, Silicon Valley and stocks were rocked by news that China's AI model may outperform  ours at a fraction of the cost and quicker to develop it.", "You've been very, in the book, you're very optimistic about AI."]
# Chunk 111: ["Last week, Silicon Valley and stocks were rocked by news that China's AI model may outperform  ours at a fraction of the cost and quicker to develop it.", "You've been very, in the book, you're very optimistic about AI.", 'Are you still optimistic and is the US falling behind China in the AI race?']
# Chunk 112: ["You've been very, in the book, you're very optimistic about AI.", 'Are you still optimistic and is the US falling behind China in the AI race?', 'Well, the US has done amazing work.']
# Chunk 113: ['Are you still optimistic and is the US falling behind China in the AI race?', 'Well, the US has done amazing work.', 'You know, both people born here and people who come here mean that we have  more AI companies than even China has.']
# Chunk 114: ['Well, the US has done amazing work.', 'You know, both people born here and people who come here mean that we have  more AI companies than even China has.', 'But we should never underestimate great innovation in China.']
# Chunk 115: ['You know, both people born here and people who come here mean that we have  more AI companies than even China has.', 'But we should never underestimate great innovation in China.', 'In many of the areas of science or getting product costs down, they do great work.']
# Chunk 116: ['But we should never underestimate great innovation in China.', 'In many of the areas of science or getting product costs down, they do great work.', "They're 20% of the world's population."]
# Chunk 117: ['In many of the areas of science or getting product costs down, they do great work.', "They're 20% of the world's population.", "So the fact that this turn of the crank, they got ahead, um, that's not totally surprising."]
# Chunk 118: ["They're 20% of the world's population.", "So the fact that this turn of the crank, they got ahead, um, that's not totally surprising.", 'The US companies will, including OpenAI, will catch up and move ahead.']
# Chunk 119: ["So the fact that this turn of the crank, they got ahead, um, that's not totally surprising.", 'The US companies will, including OpenAI, will catch up and move ahead.', 'Um, the pace of advance is pretty fantastic.']
# Chunk 120: ['The US companies will, including OpenAI, will catch up and move ahead.', 'Um, the pace of advance is pretty fantastic.', 'Mm-hmm.']
# Chunk 121: ['Um, the pace of advance is pretty fantastic.', 'Mm-hmm.', "And in many ways, that's, uh, gonna help us in education and health delivery."]
# Chunk 122: ['Mm-hmm.', "And in many ways, that's, uh, gonna help us in education and health delivery.", "A lot of good things that can come out of this that aren't zero sum."]
# Chunk 123: ["And in many ways, that's, uh, gonna help us in education and health delivery.", "A lot of good things that can come out of this that aren't zero sum.", 'That, you know, having all countries have access, including poor countries,  uh, I think is, is very exciting.']
# Chunk 124: ["A lot of good things that can come out of this that aren't zero sum.", 'That, you know, having all countries have access, including poor countries,  uh, I think is, is very exciting.', "I have to ask you this because of my obsession with, uh, social media and where it's going."]
# Chunk 125: ['That, you know, having all countries have access, including poor countries,  uh, I think is, is very exciting.', "I have to ask you this because of my obsession with, uh, social media and where it's going.", "We noticed you haven't tweeted in a while, but this past weekend, you joined TikTok, Bill Gates."]
# Chunk 126: ["I have to ask you this because of my obsession with, uh, social media and where it's going.", "We noticed you haven't tweeted in a while, but this past weekend, you joined TikTok, Bill Gates.", 'Why did you join the platform?']
# Chunk 127: ["We noticed you haven't tweeted in a while, but this past weekend, you joined TikTok, Bill Gates.", 'Why did you join the platform?', 'Where do you come down on the impact of social media more broadly, especially with, uh,  Meta banning fact-checking?']
# Chunk 128: ['Why did you join the platform?', 'Where do you come down on the impact of social media more broadly, especially with, uh,  Meta banning fact-checking?', 'Do you do dance numbers on TikTok?']
# Chunk 129: ['Where do you come down on the impact of social media more broadly, especially with, uh,  Meta banning fact-checking?', 'Do you do dance numbers on TikTok?', 'Or...']
# Chunk 130: ['Do you do dance numbers on TikTok?', 'Or...', 'Whatever it takes to sell books.']
# Chunk 131: ['Or...', 'Whatever it takes to sell books.', 'Really?']
# Chunk 132: ['Whatever it takes to sell books.', 'Really?', "I'm available."]
# Chunk 133: ['Really?', "I'm available.", 'Uh...']
# Number of sentences: 135
# Total number of words: 1320

# %%
import logging
from sentence_transformers import SentenceTransformer

# Set logging to INFO level so that you can see more details in console output
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(message)s', level=logging.INFO)

sentences = chunks  # your list of sentences
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# Encode with the progress bar enabled
embeddings = model.encode(sentences, show_progress_bar=True, batch_size=32)
# Out:
# 2025-04-08 18:44:57,720 - INFO - Use pytorch device_name: cuda:0
# 2025-04-08 18:44:57,720 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# 2025-04-08 18:44:57,720 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# Small code snippet to estimate the token count of the conversation text for OpenAI API
import tiktoken

# Choose the model name for which you want to count tokens; e.g., "gpt-4"
model_name = "gpt-4"
enc = tiktoken.encoding_for_model(model_name)

# Flatten the conversation list to a single string
conversation_text = " ".join(conversation)

num_tokens = len(enc.encode(conversation_text))
print(f"Estimated token count: {num_tokens}")
# Out:
# Estimated token count: 1770

# %%
import numpy as np
# Method to fancy print some statistics about the embeddings
def print_statistics(embeddings):
    """
    Print statistics about the embeddings.
    
    Args:
        embeddings (list): List of embeddings.
    """
    
    print(f"Number of sentences: {len(embeddings)}")
    print(f"Embedding size: {len(embeddings[0])}")
    print(f"First embedding: {embeddings[0][:5]}...")  # Print first 5 dimensions
    print(f"Size of file: {os.path.getsize('exampleConversation_embeddings.npy') / (1024 * 1024):.2f} MB")


# Save the embeddings to a file
embeddings_file = "exampleConversation_embeddings.npy"
np.save(embeddings_file, embeddings)
print(f"Embeddings saved to {embeddings_file}")

# Print statistics about the embeddings
print_statistics(embeddings)
# Out:
# Embeddings saved to exampleConversation_embeddings.npy
# Number of sentences: 133
# Embedding size: 768
# First embedding: [-0.02305532  0.0953411   0.01701605  0.01112299 -0.02063525]...
# Size of file: 0.39 MB

# %%
import numpy as np

# Function to compute cosine similarity between two vectors
def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# Function to find the top k most similar segments given a query
def find_top_k(query, embeddings, sentences, k=2):
    # Compute the embedding for the query
    query_embedding = model.encode([query])[0]
    
    # Compute cosine similarities between query and each embedding
    similarities = np.array([cosine_similarity(query_embedding, emb) for emb in embeddings])
    
    # Get indices of the top k most similar embeddings (higher similarity first)
    top_k_indices = similarities.argsort()[-k:][::-1]
    
    # Return the corresponding text segments with their similarity scores
    return [(sentences[i], similarities[i]) for i in top_k_indices]

# Example usage
query = input("Enter a query: ")
results = find_top_k(query, embeddings, chunks, k=3)

print("\nTop relevant conversation segments:")
for i, (segment, score) in enumerate(results, start=1):
    print(f"{i}. (Score: {score:.3f}) {segment}")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Top relevant conversation segments:
# 1. (Score: 0.821) ["And it won't be the last pandemic.", 'The next one could be far more severe.', 'I mean, this one, it killed millions.']
# 2. (Score: 0.717) ['Yeah, the pandemic, sadly, was fairly predictable.', "And it won't be the last pandemic.", 'The next one could be far more severe.']
# 3. (Score: 0.708) ['I was reading, though, that you said the next pandemic, you are predicting within maybe 25 years.', 'Is that accurate?', "Oh, certainly we'll have one in the next 25 years."]
